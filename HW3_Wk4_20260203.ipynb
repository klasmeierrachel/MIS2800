# %% [markdown]
# <a href="https://colab.research.google.com/github/klasmeierrachel/MIS2800/blob/main/HW3_Wk4_20260203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The next six blocks provide the exact code to run to get your Colab file started to run SQLite3

# %%
# !pip install --upgrade pandas==2.2.2 ipython-sql prettytable==3.10.1

# %%
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///AdCampaigns2026.db

# %%
#Block 1
# Instructions: There is a typo in the table.  Hint: a word is missing.
# %%sql
CREATE TABLE Marketing_Brands (
  brand_id INTEGER PRIMARY KEY,
  brand_name TEXT,
  brand_type TEXT,
  brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
#Block 2
# Instructions: Find and fix the error.
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 100000),
  (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
#Block 3
# -- Instructions: Fix the code to select all the columns
# from the Marketing_Brands table
# %%sql
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 4
# -- Instructions: Fix the code to display only the brand names and
# brand types that had budget over 700000
# %%sql
SELECT brand_name, brand_type FROM Marketing_Brands WHERE brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('Google', 'Technology')]

# %%
#Block 5
# %%sql
-- Instructions: Fix the code to find the brand types that are Religious
SELECT brand_type FROM Marketing_Brands WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Religious',)]

# %%
#Block 6
# -- Instructions: Fix the code to display the
# brand names that have a budget under 1000000
# %%sql
SELECT brand_name FROM Marketing_Brands WHERE brand_budget < 1000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('IBM',)]

# %%
#Block 7
# Instructins: Fix the code so that this will run SQLite3 in
# Colab without having to wrap in Python.  Hint: It's Magic!
# %%sql
SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8
# %%sql
--Instructions: Find the brands where the brand type is Snacks or Beverages.  Display only the brand names.
SELECT brand_name FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
#Block 9
# %%sql
-- Instructions: Sort the table by brand budget in
-- DESC order. Display only the brand_name and brand_budget.
SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
#Block 10
# Using SQLite3 (and all its magic) to create a
# table showing all the columns in ascending order by budget.
# %%sql
SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# 1. How did you fix the error in Block #1? TABLE was missing from create table
# 2. How did you fix the error in Block #2? Answer: I added INTO Marketing_Brands after inset to change the table
# 3. How did you fix the error in Block #3? Answer: I added SELECT * FROM Marketing_Brands;
# 4. How did you fix the error in Block #4? Answer: I added brand_name, brand_type before the from then WHERE brand_budget > 700000; after marketing_brands
# 5. How did you fix the error in Block #5? Answer: I added SELECT brand_type FROM Marketing_Brands WHERE brand_type = 'Religious';
# 6. How did you fix the error in Block #6? Answer: I added SELECT brand_name FROM Marketing_Brands WHERE brand_budget < 1000000; before and after Marketing_brands
# 7. How did you fix the error in Block #7? Answer: I added the selct * and the number perameters
# 8. How did you fix the error in Block #8? Answer: I added the WHERE brand_type = 'Snacks' OR brand_type = 'Beverages'; perameters
# 9. How did you fix the error in Block #9? Answer: I added brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC; to make it so this is in a table and in the right order
# 10. How did you fix the error in Block #10? Answer: I added %%sql
# SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
